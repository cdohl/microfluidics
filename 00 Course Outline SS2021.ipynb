# %% [markdown]
# ### Course Outline
#
# Welcome to the new semester, this time fully online. We start with an introduction of what fluids (gases and liquids) are and set the foundation for the first part of the course on *microfluidics*.
#
# ## Week 1: General Introduction (6.4.2021)
#
# We will cover the adminstration and give a introduction into fluid mechanics and microfluidics in particular.
#
# Gases and liquids can be modeled with particles (non interacting and interacting). Molecular dynamics (MD) simulations help to understand their behaviour and watch them in slow motion. To get into the mood of using averaged equations I want you to play with a MD program. It can be [run in your browser](http://cav2012.sg/cdohl/ph3501/md/). For more information on how to run the program is available  [web site from Prof Schroeder](http://physics.weber.edu/schroeder/md/), please note that this version does not have the pressure graph.
#
# To get us all started, we rehearse some math. Please look and work through the [Math refresher notebook](01 Math Refresher and Python Introduction.ipynb). This notebook also offers you with some first introduction into Python, the language we use in the course. A nice [introduction is given by Robert Johansson](http://nbviewer.jupyter.org/github/jrjohansson/scientific-python-lectures/blob/master/Lecture-1-Introduction-to-Python-Programming.ipynb). Don't worry, we will slowly start with it. I'll motivate the use of a programming language in the course, and besides learning fluid mechanics you obtain some skills which increases your employability!
#
# We have a short recap on the
# * [math](01%20Math%20Refresher%20and%20Python%20Introduction.ipynb) and the representation in Python
# then we'll look into the
# * [streamlines, streaklines, and pathlines](02%20Streamlines,%20Pathlines,%20Streaklines.ipynb) and use a [interactive example](Example%20of%20Stream-Streak-Pathlines.ipynb) before we look at the
#
#
# ## Week 2: Intro to Microfluidics & Derivation of the Conservation of Mass
#
# Short introduction to microfluidics plus 3 videos are available on youtube here:
# [Video 1](https://www.youtube.com/watch?v=b8zE2i755-k), [Video 2](https://www.youtube.com/watch?v=68p3qAm4i7U), and [Video 3](https://www.youtube.com/watch?v=EYuyRUjnTgc).
#
# Soft mathematical introduction to fluid mechanics. We start with the [material derivative](Material%20Derivative,%20Gaussian%20Divergence%20Theorem%20and%20Conservation%20of%20Mass.ipynb) and also introduce the *Gaussian Divergence Theorem* and the *Conservation of Mass*. It is important that you understand the [Eulerian description](https://en.wikipedia.org/wiki/Lagrangian_and_Eulerian_specification_of_the_flow_field) of flows.
#
# ### Tutorial 1 (Week 2):
#
# See Tutorial Sheet on E-Learning
#
#
# ## Week 3: Navier Stokes equation derivation and first analytical solutions
#
# [In this Notebook](Cauchy's%20Equation%20of%20Motion%20&%20Navier%20Stokes%20Equation.ipynb) we first derive the Cauchy's Equation of Motion for a continuum from Newton's 2nd Law of Motion for a deformable object. Then we insert the surface stresses for a linear fluid and through simplification obtain the Navier Stokes Equation for a incompressible and constant viscosity fluid. Then we look at some solution of a [numerical flow solver](13a_Navier%20Stokes%20example.ipynb).
#
#
# ## Week 4:
# We discuss analytical solutions to the Navier Stokes Equation in [planar and cylindrical symmetry](Analytical%20solutions%20to%20steady%20and%20laminar%20flows.ipynb) and [Dimensional Analysis](Dimensional%20Analysis%20of%20the%20Navier%20Stokes%20Equation.ipynb).
#
# ### Tutorial 2 (Week 4):
# **Question A Flow Simulations**
#
# 1. Write down the boundary conditions for the velocity $\vec{u}$ and pressure for a flow in a 2d-tube driven by a pressure gradient. You need one for each boundary, i.e. the walls and the inlet/outlet, and component of the velocity. The pressure at the walls are determined by the incompressibility condition. For help look into the code.
# 2. Do the same for a flow in a 2-tube driven by the upper wall. Again, check you answer with the boundary conditions stated in the code.
# 3. Conduct simulations for pressure driven and wall driven flows. Try to obtain a parabolic profile for the pressure driven flow and a linear profile for the wall driven flow. Discuss the results. What is the effect of the time step of integration, and the CFL-number. Look up the meaning of the CFL number.
#
# ** Question B Index Notation**
#
# Use the index notation and work out the following problems
#
# 1. $$\frac{\partial}{\partial x_i}(p\,\delta_{ij})=(\nabla p)_j$$
# 2. $$\nabla\cdot(\rho \vec{u})=(\nabla \rho)\cdot \vec{u}+\rho\,\nabla\cdot\vec{u}$$
#
# ** Question C Navier Stokes Equation**
#
# The electrostatic force is a body force $\vec{F}=q\,\vec{E}$, where $q$ is the charge and $\vec{E}$ is the electric field. Add this force in the derivation of the Navier Stokes Equation and write a Navier Stokes Eq. with electrostatic body forces using a charge density $\rho_{el}$ and the electric field $\vec{E}$.
#
# ## Week 5
#
# Navier Stokes solution to an [unsteady problem](Analytical%20Solution%20to%20an%20unsteady%20flow.ipynb) (Stoke's first problem) and comparison with the CFD solver. For inviscid flows we simplify the Navier Stokes Eq. to the [Bernoulli equation](Bernoulli%20Equation.ipynb).
#
#
# ## Week6
#
# Application of the [Unsteady Bernoulli Equation](Example%20of%20unsteady%20Bernoulli%20equation.ipynb) for the collapse of a spherical void. Introduction to [potential flow](Ideal%20Flow%20&%20Solutions%20to%20the%20Laplace%20Equation.ipynb).
#
# ## Tutorial 3 (Week 6)
#
# ### Question 1
#
# Repeat the Navier Stokes derivation for a tube now for 2 concentric tubes with radii $r_i$ and $r_o$.
# <img src="files/pics/concentric tubes.png" width=400>
# Show that the flow velocity in $z$-direction is
# $$
# u_z(r)=\frac{1}{4\mu}\frac{\mathrm{d}p}{\mathrm{d}z}\left(r^2-r_o^2+\frac{r_i^2-r_o^2}{\ln \frac{r_o}{r_i}}\ln\left[\frac{r}{r_i}\right]\right)\quad .$$
#
# ### Question 2
#
# We'll read and discuss two microfluidic papers to get a feeling on the making and running of  a microfluidic system. The two papers are available here
# * [Cavitation in flow through a micro-orifice inside a silicon microchannel](pdf/manufacture%20microfluidic%20venturi.pdf) from Chandan Mishra, and Yoav Peles. This paper describes the manufacturing process of glass bonded Si chips for high-pressure water flows.
# * [An experimental investigation of hydrodynamic cavitation in micro-Venturis](pdf/microfluidic%20venturi.pdf) from Chandan Mishra, and Yoav Peles. This paper describes a venturi and the phase transition of the liquid into vapor.
#
# Work in two groups. The first group focuses reading and understanding on manufacturing. Try to answer the questions:
# 1. Explain the use of a photoresist.
# 2. What is the difference of SiO and pure Si surface to RIE and DRIE processes?
# 3. Where is anodic bonding used.
# 4. How is the device mounted in the holder and connected to the tubing?
#
# The second group looks at the experimental paper (cavitation in micro-Venturis).
# 1. The cavitation number and the Reynolds number are defined. Check their values for the experimental protocols. Is it a low or high-Reynolds number flow? What dominates, inerta or viscosity?
# 2. Why does a low cavitation number result in more vapor generation?
# 3. Summarize the regimes of cavitation observed in the experiment.
#
#
# ## Week 7
# Derivation of the force on a sphere [in potential flow](Potential%20Sphere.ipynb) and in a viscous flow, i.e. the [Stokes Sphere](Stokes%20Sphere.ipynb) problem. We will also look at a viscous microfluidic flow with a potential flow solution, the [Hele Shaw flow](Hele%20Shaw%20Flow.ipynb).
#
# ## Tutorial 4 (Week 8)
#
# ### Question 1
# <img src="files/pics/inclined_flow.png" width=500>
#
# * Derive the Navier Stokes Solution to the steady flow of a film of liquid of uniform thickness $h$ that flows done an incline (dark gray) under an angle $\alpha$. Use the fact that there is no pressure gradient driving the flow (why?). Also set the $x$-axis parallel to the incline and choose a suitable body force.
#
# * Let the liquid be water and calculate the speed $v_x(h)$ of the free surface of the film in the case $h=100\,\mu$m und angle $\alpha=30^\circ$.
#
# ### Question 2
#
# * Look up literature on the Milikan Experiment. Find out how the Stokes Law $F_D=6\pi\mu R U$ was used to determine the charge of an electron. Sketch the forces acting on a droplet and explain who the experiment was conducted in detail.
#
#
# ### Question 3
#
# * Aerosols are fine droplets in the air that may contain viral load. In the current pandemic researcher are trying to understand the transport of these droplets. In a quiestence room with no drift (net flow) of the air, droplets may fall by gravity. Calculate and plot the fall time of an aequous droplet from $100\,$nm to $10\,\mu$ spherical droplet in air for a distance of $30\,$cm. Check and compare your findings with a recent [paper](https://www.pnas.org/content/early/2020/05/12/2006874117). Comment critically this paper.
#
# ## Week 8
# Microfluidic systems (Lab on a Chip) are composed typically out of inlets, outlets, and one or many connecting channels. In this lecture we will develop a strategy to describe these connected channel networks with a hydraulic [Resistance](Hydraulic%20resistance.ipynb). Additionally we will have a brief look into simulating a flow with comutational fluid dynamics (CFD).
#
# ## Week 9
# We will look at the basic principle of diffusion and discuss several solutions of the diffusion equation in this [section](Diffusion.ipynb).
#
# ## Tutorial 5 (Week 10)
#
#
# ### Question 1
# <img src="pics/microfluidic_mixer.png" width=500px>
#
# The micro-mixer above is designed to obtain a well-controlled mix of six different chemicals dissolved in water. Assume that all six inlet pressures are the same, $p_0 + \Delta p$, and that the outlet pressure is $p_0$.
#
# a. Draw the equivalent circuit diagram of the mixer.
#
# b. Calculate the total hydraulic resistance of the micro-mixer.
#
# ### Question 2
#
# Demonstrate with a program that $l_\text{diff, N}^\text{1D}\propto \sqrt{N}$ for the 1D random walk by plotting it as function of $\sqrt{N}$. Now modify the steps to $l=+2$ in the forward direction and $l=-1$ in the backward direction. What do you observed? Discuss.
#
# ### Question 3
#
# The nondimensional Peclet number, $Pe$, is the ratio between the time for diffusion and time for convection.
#
# a. Derive an expression for the Peclet number for a one-dimensional geometry with length $L$, velocity $u$ und diffusion constant $D$.
#
# b. Rewrite the convection diffusion equation in non-dimensional variables and use there the $Pe$ number.
#
# c. Discuss the non-dimensional diffusion equation in the limits of small and large $Pe$ numbers.
#
#
# ## Week 10
# [Capillarity](Capillarity.ipynb) is the force acting at interfaces between solids, gases and liquids. Here we'll start from the basic concept of the Gibbs free energy to the Young-Laplace equation and the Young-Equation. We'll see that a surface tries to maintain minimum area within the constraints set. We'll have a look at the rise and rise velocity of a vertical microcapillary and the pumping of liquid of an initialy dry microfluidic channel. If you want to dive further I strongly recommend the book [Capillarity and Wetting Phenomena](https://link.springer.com/book/10.1007%2F978-0-387-21656-0) by  Pierre-Gilles de Gennes, Francoise Brochard-Wyart, Davide Quere.
#
# ## Week 11
# [Two-phase flows](Two%20Phase%20Flows.ipynb)
#
#
#
# ## Week 12
# [Electrohydrodynamics & Electrodynamics](Electrosomotic%20flow.ipynb)
#
#
# ## Week 13
# Presentations 1
#
# ## Tutorial 6 (Week 13)
#
#
# #### Capillarity
# Find the expression for the Young–Laplace pressure drop across a liquid/gas interface with surface tension coefficient $\gamma$ inside a flat and very wide rectangular channel of height $h$, where the contact angle for the bottom and top plate are given by $\theta_1$ and $\theta_2$, respectively.
#
#
# #### Two-Phase Flow
# 1. Derive the expressions for $h_1$ and $h_2$ for the two-phase Poiseuille flow in Chapter [Two-Phase Flows](Two Phase Flows.ipynb). Discuss the limits of $\mu_1\rightarrow 0$ and $\mu_2\righarrow \infty$ if they make sense.
#
# 2. The dispersion relation $\omega(k)$ for gravity waves is given by Eq. (20) in Chapter Two-Phase Flows](Two Phase Flows.ipynb). Discuss the physical interpretation of this expression for $\rho_1 > \rho_2$ and for $\rho_1 < \rho_2$. Does the finding relate with your experiences, if yes give examles. Hint: consider the time evolution using the complex notation $e^{−iωt}$ for the time dependence.
#
# #### Electrosmotic Flow
# Plot the electric potential and the flow profile for the electric osmotic flow in a infinitely long flow channel as a function of $z$. Start with the program in Chapter [Electrosomotic flow](Electrosomotic%20flow.ipynb).
# Derive from Eq. (27) in Chapter [Electrosomotic flow](Electrosomotic%20flow.ipynb) the flow rate $Q$ through the thin channel.
#
#
# ## Week 14
# Presentations 2
